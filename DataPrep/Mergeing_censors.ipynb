# %%
import sys
sys.path.append("..")
# %cd ..
# Out:
# c:\Users\frede\OneDrive - Danmarks Tekniske Universitet\DTU\6. Semester\Bachelor2021-1

# %%
from DataPrep.load_data import load_data
import pyforest

# %%
df = load_data()
plugs = pd.read_csv("data\createdDat\Censorship_scheem\Plugs_censord.csv")
plugs["Start Date"] = pd.to_datetime(plugs["Start Date"])
#plugs = plugs.set_index("Start Date")

# %%
df["Start Date"] = df.index

# %%
df_censored = df.merge(plugs[["Label","Energy (kWh)", "Fee (USD)","Censored","Start Date"]], on=["Start Date","Label"]).set_index("Start Date")

# %%
censored_from = pd.to_datetime(['2017-07-05','2018-03-23','2011-08-02', '2017-01-06', '2014-10-05', '2015-01-02', '2018-03-22', '2016-01-14'])
for label in range(8):
    plt.plot(df_censored[df_censored["Label"]==label]["Energy (kWh)_x"], label="df_days_with_external_11052021 / Data from Load")
    plt.plot(df_censored[df_censored["Label"]==label]["Energy (kWh)_y"], alpha=0.5, label="Censored data")
    plt.vlines(censored_from[label],label=f"Censored from this date {censored_from[label].date()}", ymin=0, ymax=max(df_censored[df_censored["Label"]==label]["Energy (kWh)_x"]), color="Red")
    plt.legend()
    plt.title(f"Label{label}")
    plt.show()
