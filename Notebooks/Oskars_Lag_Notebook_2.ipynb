# %%
import numpy as np
import pandas as pd
import datetime as dt
import time
import matplotlib.pyplot as plt

# %%
from Data_cleaning import clean_paloalto

# %%
c = clean_paloalto() 
data = c.clean_data()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3338: DtypeWarning: Columns (29,30,32,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# C:\Users\User\OneDrive - Danmarks Tekniske Universitet\SAS_030919\6. Semester\BSc\Bachelor2021\Data_cleaning.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Charge Duration (mins)"][df["Charge Duration (mins)"]==" -   "]=0

# %%
data.head(1)
# Out:
#                  Station Name       MAC Address           Org Name  \
# 0  PALO ALTO CA / HAMILTON #1  000D6F00015A9D76  City of Palo Alto
#
#            Start Date Start Time Zone            End Date End Time Zone  \
# 0 2011-07-29 20:17:00             PDT 2011-07-29 23:20:00           PDT
#
#   Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 0       1900-01-01 03:03:32      1900-01-01 01:54:03      6.249457  ...
#
#    Longitude  Currency  Fee             Ended By Plug In Event Id  \
# 0  -122.1603       USD  0.0  Plug Out at Vehicle                3
#
#   Driver Postal Code Park Duration (mins) Charge Duration (mins)  ID  \
# 0              95124                 184                   114.0   0
#
#         Pairlocation
# 0  37.4446x-122.1603
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Complementary Data cleaning

# %%
data['Charging Time (hh:mm:ss)'] = data['Charging Time (hh:mm:ss)'] - dt.datetime(1900, 1, 1, 0, 0, 0)
data['Total Duration (hh:mm:ss)'] = data['Total Duration (hh:mm:ss)'] - dt.datetime(1900, 1, 1, 0, 0, 0)

# %%
data['Charging Time (hh:mm:ss)'] = data['Charging Time (hh:mm:ss)'].round('min')
data['Total Duration (hh:mm:ss)'] = data['Total Duration (hh:mm:ss)'].round('min')

# %%
data.head(1)
# Out:
#                  Station Name       MAC Address           Org Name  \
# 0  PALO ALTO CA / HAMILTON #1  000D6F00015A9D76  City of Palo Alto
#
#            Start Date Start Time Zone            End Date End Time Zone  \
# 0 2011-07-29 20:17:00             PDT 2011-07-29 23:20:00           PDT
#
#   Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 0           0 days 03:04:00          0 days 01:54:00      6.249457  ...
#
#    Longitude  Currency  Fee             Ended By Plug In Event Id  \
# 0  -122.1603       USD  0.0  Plug Out at Vehicle                3
#
#   Driver Postal Code Park Duration (mins) Charge Duration (mins)  ID  \
# 0              95124                 184                   114.0   0
#
#         Pairlocation
# 0  37.4446x-122.1603
#
# [1 rows x 31 columns]

# %%
data.dtypes
# Out:
# Station Name                           object
# MAC Address                            object
# Org Name                               object
# Start Date                     datetime64[ns]
# Start Time Zone                        object
# End Date                       datetime64[ns]
# End Time Zone                          object
# Total Duration (hh:mm:ss)     timedelta64[ns]
# Charging Time (hh:mm:ss)      timedelta64[ns]
# Energy (kWh)                          float64
# GHG Savings (kg)                      float64
# Gasoline Savings (gallons)            float64
# Port Type                              object
# Port Number                             int64
# Plug Type                              object
# Address 1                              object
# City                                   object
# State/Province                         object
# Postal Code                             int64
# Country                                object
# Latitude                              float64
# Longitude                             float64
# Currency                               object
# Fee                                   float64
# Ended By                               object
# Plug In Event Id                        int64
# Driver Postal Code                     object
# Park Duration (mins)                   object
# Charge Duration (mins)                float64
# ID                                      int64
# Pairlocation                           object
# dtype: object

# %%
data['StartYear'] = data['Start Date'].dt.year

df16 = data[data['StartYear'] == 2016]
df16.head()
# Out:
#                          Station Name       MAC Address            Org Name  \
# 49689  PALO ALTO CA / RINCONADA LIB 1  000D6F00009DCC2B  City of Palo Alto
# 49690        PALO ALTO CA / BRYANT #2  000D6F00009DCFC3  City of Palo Alto
# 49691        PALO ALTO CA / BRYANT #1  000D6F0000A20D9E  City of Palo Alto
# 49692           PALO ALTO CA / MPL #6  000D6F00015B7509  City of Palo Alto
# 49693       PALO ALTO CA / WEBSTER #1  0024B10000021146  City of Palo Alto
#
#                Start Date Start Time Zone            End Date End Time Zone  \
# 49689 2016-01-01 02:00:00             PST 2016-01-01 12:04:00           PST
# 49690 2016-01-01 09:26:00             PST 2016-01-01 11:19:00           PST
# 49691 2016-01-01 09:55:00             PST 2016-01-01 10:49:00           PST
# 49692 2016-01-01 10:13:00             PST 2016-01-01 12:05:00           PST
# 49693 2016-01-01 10:42:00             PST 2016-01-01 13:59:00           PST
#
#       Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 49689           0 days 10:04:00          0 days 03:06:00     10.072230  ...
# 49690           0 days 01:53:00          0 days 01:30:00      2.744629  ...
# 49691           0 days 00:54:00          0 days 00:54:00      5.233959  ...
# 49692           0 days 01:53:00          0 days 01:52:00     11.342517  ...
# 49693           0 days 03:16:00          0 days 03:16:00     16.388630  ...
#
#        Currency  Fee             Ended By  Plug In Event Id  \
# 49689       USD  0.0             Customer              1356
# 49690       USD  0.0  Plug Out at Vehicle              6652
# 49691       USD  0.0             Customer              9684
# 49692       USD  0.0  Plug Out at Vehicle              2073
# 49693       USD  0.0  Plug Out at Vehicle              1368
#
#       Driver Postal Code Park Duration (mins) Charge Duration (mins)  ID  \
# 49689              94303                 604                   186.0  13
# 49690              94301                 113                    90.0   5
# 49691              95070                  54                    54.0   4
# 49692              94306                 113                   112.0   7
# 49693              94301                 196                   196.0  15
#
#             Pairlocation StartYear
# 49689  37.4455x-122.1389      2016
# 49690  37.4465x-122.1621      2016
# 49691  37.4466x-122.1623      2016
# 49692  37.4221x-122.1135      2016
# 49693  37.4483x-122.1583      2016
#
# [5 rows x 32 columns]

# %%
df16one = df16[df16['Station Name'] == 'PALO ALTO CA / WEBSTER #2']
df16one.head()
# Out:
#                     Station Name       MAC Address            Org Name  \
# 49698  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49710  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49732  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49736  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49745  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
#
#                Start Date Start Time Zone            End Date End Time Zone  \
# 49698 2016-01-01 11:48:00             PST 2016-01-01 15:39:00           PST
# 49710 2016-01-01 13:43:00             PST 2016-01-01 17:28:00           PST
# 49732 2016-01-01 22:43:00             PST 2016-01-02 10:31:00           PST
# 49736 2016-01-02 07:09:00             PST 2016-01-02 09:38:00           PST
# 49745 2016-01-02 10:29:00             PST 2016-01-02 13:05:00           PST
#
#       Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 49698           0 days 03:50:00          0 days 01:32:00      3.034643  ...
# 49710           0 days 03:45:00          0 days 03:45:00     12.427662  ...
# 49732           0 days 11:48:00          0 days 01:51:00     10.752058  ...
# 49736           0 days 02:29:00          0 days 02:29:00     11.160776  ...
# 49745           0 days 02:36:00          0 days 02:36:00     10.298505  ...
#
#        Currency  Fee             Ended By  Plug In Event Id  \
# 49698       USD  0.0             Customer              1216
# 49710       USD  0.0  Plug Out at Vehicle              1219
# 49732       USD  0.0  Plug Out at Vehicle        1451717005
# 49736       USD  0.0  Plug Out at Vehicle              1220
# 49745       USD  0.0  Plug Out at Vehicle              1221
#
#       Driver Postal Code Park Duration (mins) Charge Duration (mins)  ID  \
# 49698              94024                 230                    92.0  17
# 49710              94025                 225                   225.0  17
# 49732              94301                 708                   111.0  17
# 49736              94303                 149                   149.0  17
# 49745              95123                 156                   156.0  17
#
#             Pairlocation StartYear
# 49698  37.4482x-122.1582      2016
# 49710  37.4482x-122.1582      2016
# 49732  37.4482x-122.1582      2016
# 49736  37.4482x-122.1582      2016
# 49745  37.4482x-122.1582      2016
#
# [5 rows x 32 columns]

# %%
import datetime as dt
df16one['StartSlot'] = df16one['Start Date'].dt.floor("2H")#apply(lambda dt: datetime.datetime(dt.year, dt.month, dt.day, 24*(dt.hour // 24))) #,15*(dt.minute // 15)))
df16one['EndSlot'] = df16one['End Date'].dt.ceil("2H")
# Out:
# <ipython-input-11-b1c0c1dc3aa7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16one['StartSlot'] = df16one['Start Date'].dt.floor("2H")#apply(lambda dt: datetime.datetime(dt.year, dt.month, dt.day, 24*(dt.hour // 24))) #,15*(dt.minute // 15)))
# <ipython-input-11-b1c0c1dc3aa7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16one['EndSlot'] = df16one['End Date'].dt.ceil("2H")

# %%
df16one.head()
# Out:
#                     Station Name       MAC Address            Org Name  \
# 49698  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49710  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49732  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49736  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49745  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
#
#                Start Date Start Time Zone            End Date End Time Zone  \
# 49698 2016-01-01 11:48:00             PST 2016-01-01 15:39:00           PST
# 49710 2016-01-01 13:43:00             PST 2016-01-01 17:28:00           PST
# 49732 2016-01-01 22:43:00             PST 2016-01-02 10:31:00           PST
# 49736 2016-01-02 07:09:00             PST 2016-01-02 09:38:00           PST
# 49745 2016-01-02 10:29:00             PST 2016-01-02 13:05:00           PST
#
#       Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 49698           0 days 03:50:00          0 days 01:32:00      3.034643  ...
# 49710           0 days 03:45:00          0 days 03:45:00     12.427662  ...
# 49732           0 days 11:48:00          0 days 01:51:00     10.752058  ...
# 49736           0 days 02:29:00          0 days 02:29:00     11.160776  ...
# 49745           0 days 02:36:00          0 days 02:36:00     10.298505  ...
#
#                   Ended By  Plug In Event Id Driver Postal Code  \
# 49698             Customer              1216              94024
# 49710  Plug Out at Vehicle              1219              94025
# 49732  Plug Out at Vehicle        1451717005              94301
# 49736  Plug Out at Vehicle              1220              94303
# 49745  Plug Out at Vehicle              1221              95123
#
#        Park Duration (mins) Charge Duration (mins)  ID       Pairlocation  \
# 49698                  230                    92.0  17  37.4482x-122.1582
# 49710                  225                   225.0  17  37.4482x-122.1582
# 49732                  708                   111.0  17  37.4482x-122.1582
# 49736                  149                   149.0  17  37.4482x-122.1582
# 49745                  156                   156.0  17  37.4482x-122.1582
#
#       StartYear           StartSlot             EndSlot
# 49698      2016 2016-01-01 10:00:00 2016-01-01 16:00:00
# 49710      2016 2016-01-01 12:00:00 2016-01-01 18:00:00
# 49732      2016 2016-01-01 22:00:00 2016-01-02 12:00:00
# 49736      2016 2016-01-02 06:00:00 2016-01-02 10:00:00
# 49745      2016 2016-01-02 10:00:00 2016-01-02 14:00:00
#
# [5 rows x 34 columns]

# %%
df16one['ConPerMin'] = df16one['Energy (kWh)'] / df16one['Charge Duration (mins)']
# Out:
# <ipython-input-13-dc299c085e8b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df16one['ConPerMin'] = df16one['Energy (kWh)'] / df16one['Charge Duration (mins)']

# %%
df16one['ConPerMin'].describe()
# Out:
# count    3320.000000
# mean             inf
# std              NaN
# min         0.000008
# 25%         0.053514
# 50%         0.076167
# 75%         0.097152
# max              inf
# Name: ConPerMin, dtype: float64

# %%
df16one['Energy (kWh)'].describe()
# Out:
# count    3320.000000
# mean       10.170776
# std         8.541733
# min         0.000008
# 25%         5.195533
# 50%         8.477313
# 75%        13.014921
# max        74.994000
# Name: Energy (kWh), dtype: float64

# %%
df16one['Charge Duration (mins)'].describe()
# Out:
# count    3320.000000
# mean      132.991867
# std        88.843795
# min         0.000000
# 25%        76.000000
# 50%       123.000000
# 75%       173.250000
# max       762.000000
# Name: Charge Duration (mins), dtype: float64

# %%
df16one = df16one.replace([np.inf], 0);
df16one['ConPerMin'].describe()
# Out:
# count    3320.000000
# mean        0.074644
# std         0.022796
# min         0.000000
# 25%         0.053450
# 50%         0.075719
# 75%         0.097126
# max         0.109847
# Name: ConPerMin, dtype: float64

# %% [markdown]
# ## NB! These could be cleaned

# %% [markdown]
# ## Creating new, empty data frame

# %%
max(df16one['StartSlot'])
# Out:
# Timestamp('2016-12-31 22:00:00')

# %%
StartSlot = min(df16one['StartSlot']) #datetime.datetime.now().date()
EndSlot = max(df16one['StartSlot'])
#index = pd.date_range(todays_date, periods=10, freq='D')
index = pd.date_range(start=StartSlot, end=EndSlot, freq="2H") #

columns = df16one.columns #['A', 'B', 'C']
 
df_fill = pd.DataFrame(index=index, columns=columns)
df_fill = df_fill.fillna(0)

# %%
df_fill
# Out:
#                      Station Name  MAC Address  Org Name  Start Date  \
# 2016-01-01 10:00:00             0            0         0           0
# 2016-01-01 12:00:00             0            0         0           0
# 2016-01-01 14:00:00             0            0         0           0
# 2016-01-01 16:00:00             0            0         0           0
# 2016-01-01 18:00:00             0            0         0           0
# ...                           ...          ...       ...         ...
# 2016-12-31 14:00:00             0            0         0           0
# 2016-12-31 16:00:00             0            0         0           0
# 2016-12-31 18:00:00             0            0         0           0
# 2016-12-31 20:00:00             0            0         0           0
# 2016-12-31 22:00:00             0            0         0           0
#
#                      Start Time Zone  End Date  End Time Zone  \
# 2016-01-01 10:00:00                0         0              0
# 2016-01-01 12:00:00                0         0              0
# 2016-01-01 14:00:00                0         0              0
# 2016-01-01 16:00:00                0         0              0
# 2016-01-01 18:00:00                0         0              0
# ...                              ...       ...            ...
# 2016-12-31 14:00:00                0         0              0
# 2016-12-31 16:00:00                0         0              0
# 2016-12-31 18:00:00                0         0              0
# 2016-12-31 20:00:00                0         0              0
# 2016-12-31 22:00:00                0         0              0
#
#                      Total Duration (hh:mm:ss)  Charging Time (hh:mm:ss)  \
# 2016-01-01 10:00:00                          0                         0
# 2016-01-01 12:00:00                          0                         0
# 2016-01-01 14:00:00                          0                         0
# 2016-01-01 16:00:00                          0                         0
# 2016-01-01 18:00:00                          0                         0
# ...                                        ...                       ...
# 2016-12-31 14:00:00                          0                         0
# 2016-12-31 16:00:00                          0                         0
# 2016-12-31 18:00:00                          0                         0
# 2016-12-31 20:00:00                          0                         0
# 2016-12-31 22:00:00                          0                         0
#
#                      Energy (kWh)  ...  Plug In Event Id  Driver Postal Code  \
# 2016-01-01 10:00:00             0  ...                 0                   0
# 2016-01-01 12:00:00             0  ...                 0                   0
# 2016-01-01 14:00:00             0  ...                 0                   0
# 2016-01-01 16:00:00             0  ...                 0                   0
# 2016-01-01 18:00:00             0  ...                 0                   0
# ...                           ...  ...               ...                 ...
# 2016-12-31 14:00:00             0  ...                 0                   0
# 2016-12-31 16:00:00             0  ...                 0                   0
# 2016-12-31 18:00:00             0  ...                 0                   0
# 2016-12-31 20:00:00             0  ...                 0                   0
# 2016-12-31 22:00:00             0  ...                 0                   0
#
#                      Park Duration (mins)  Charge Duration (mins)  ID  \
# 2016-01-01 10:00:00                     0                       0   0
# 2016-01-01 12:00:00                     0                       0   0
# 2016-01-01 14:00:00                     0                       0   0
# 2016-01-01 16:00:00                     0                       0   0
# 2016-01-01 18:00:00                     0                       0   0
# ...                                   ...                     ...  ..
# 2016-12-31 14:00:00                     0                       0   0
# 2016-12-31 16:00:00                     0                       0   0
# 2016-12-31 18:00:00                     0                       0   0
# 2016-12-31 20:00:00                     0                       0   0
# 2016-12-31 22:00:00                     0                       0   0
#
#                      Pairlocation  StartYear  StartSlot  EndSlot  ConPerMin
# 2016-01-01 10:00:00             0          0          0        0          0
# 2016-01-01 12:00:00             0          0          0        0          0
# 2016-01-01 14:00:00             0          0          0        0          0
# 2016-01-01 16:00:00             0          0          0        0          0
# 2016-01-01 18:00:00             0          0          0        0          0
# ...                           ...        ...        ...      ...        ...
# 2016-12-31 14:00:00             0          0          0        0          0
# 2016-12-31 16:00:00             0          0          0        0          0
# 2016-12-31 18:00:00             0          0          0        0          0
# 2016-12-31 20:00:00             0          0          0        0          0
# 2016-12-31 22:00:00             0          0          0        0          0
#
# [4387 rows x 35 columns]

# %% [markdown]
# ## Looking at individual chargings

# %%
test = df16one.copy() #head(1)
test
# Out:
#                     Station Name       MAC Address            Org Name  \
# 49698  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49710  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49732  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49736  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 49745  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# ...                          ...               ...                 ...
# 95322  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 95325  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 95346  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 95353  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
# 95360  PALO ALTO CA / WEBSTER #2  0024B100000207FA  City of Palo Alto
#
#                Start Date Start Time Zone            End Date End Time Zone  \
# 49698 2016-01-01 11:48:00             PST 2016-01-01 15:39:00           PST
# 49710 2016-01-01 13:43:00             PST 2016-01-01 17:28:00           PST
# 49732 2016-01-01 22:43:00             PST 2016-01-02 10:31:00           PST
# 49736 2016-01-02 07:09:00             PST 2016-01-02 09:38:00           PST
# 49745 2016-01-02 10:29:00             PST 2016-01-02 13:05:00           PST
# ...                   ...             ...                 ...           ...
# 95322 2016-12-31 14:53:00             PST 2016-12-31 19:51:00           PST
# 95325 2016-12-31 15:01:00             PST 2016-12-31 17:14:00           PST
# 95346 2016-12-31 17:49:00             PST 2016-12-31 19:59:00           PST
# 95353 2016-12-31 20:17:00             PST 2016-12-31 20:37:00           PST
# 95360 2016-12-31 23:26:00             PST 2017-01-01 10:23:00           PST
#
#       Total Duration (hh:mm:ss) Charging Time (hh:mm:ss)  Energy (kWh)  ...  \
# 49698           0 days 03:50:00          0 days 01:32:00      3.034643  ...
# 49710           0 days 03:45:00          0 days 03:45:00     12.427662  ...
# 49732           0 days 11:48:00          0 days 01:51:00     10.752058  ...
# 49736           0 days 02:29:00          0 days 02:29:00     11.160776  ...
# 49745           0 days 02:36:00          0 days 02:36:00     10.298505  ...
# ...                         ...                      ...           ...  ...
# 95322           0 days 04:58:00          0 days 02:49:00     16.557000  ...
# 95325           0 days 02:13:00          0 days 02:13:00     13.012000  ...
# 95346           0 days 02:10:00          0 days 01:31:00      2.970000  ...
# 95353           0 days 00:20:00          0 days 00:20:00      1.022000  ...
# 95360           0 days 10:57:00          0 days 09:54:00     58.984000  ...
#
#        Plug In Event Id  Driver Postal Code Park Duration (mins)  \
# 49698              1216               94024                 230
# 49710              1219               94025                 225
# 49732        1451717005               94301                 708
# 49736              1220               94303                 149
# 49745              1221               95123                 156
# ...                 ...                 ...                  ...
# 95322              4215               94301                 298
# 95325              4216               94087                 133
# 95346              4217               94539                 130
# 95353              4218               95134                  20
# 95360              4220               94301                 657
#
#        Charge Duration (mins)  ID       Pairlocation StartYear  \
# 49698                    92.0  17  37.4482x-122.1582      2016
# 49710                   225.0  17  37.4482x-122.1582      2016
# 49732                   111.0  17  37.4482x-122.1582      2016
# 49736                   149.0  17  37.4482x-122.1582      2016
# 49745                   156.0  17  37.4482x-122.1582      2016
# ...                       ...  ..                ...       ...
# 95322                   169.0  17  37.4482x-122.1582      2016
# 95325                   133.0  17  37.4482x-122.1582      2016
# 95346                    91.0  17  37.4482x-122.1582      2016
# 95353                    20.0  17  37.4482x-122.1582      2016
# 95360                   594.0  17  37.4482x-122.1582      2016
#
#                 StartSlot             EndSlot ConPerMin
# 49698 2016-01-01 10:00:00 2016-01-01 16:00:00  0.032985
# 49710 2016-01-01 12:00:00 2016-01-01 18:00:00  0.055234
# 49732 2016-01-01 22:00:00 2016-01-02 12:00:00  0.096865
# 49736 2016-01-02 06:00:00 2016-01-02 10:00:00  0.074905
# 49745 2016-01-02 10:00:00 2016-01-02 14:00:00  0.066016
# ...                   ...                 ...       ...
# 95322 2016-12-31 14:00:00 2016-12-31 20:00:00  0.097970
# 95325 2016-12-31 14:00:00 2016-12-31 18:00:00  0.097835
# 95346 2016-12-31 16:00:00 2016-12-31 20:00:00  0.032637
# 95353 2016-12-31 20:00:00 2016-12-31 22:00:00  0.051100
# 95360 2016-12-31 22:00:00 2017-01-01 12:00:00  0.099300
#
# [3320 rows x 35 columns]

# %%
result = pd.DataFrame()
result2 = pd.concat([result, final])
result2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f9d500796d3f> in <module>
#       1 result = pd.DataFrame()
# ----> 2 result2 = pd.concat([result, final])
#       3 result2
#
# NameError: name 'final' is not defined

# %%
result = pd.DataFrame()


start = time.time()


for index, row in test.iterrows():

    dftemp = pd.DataFrame(row).T
    dftemp.insert(0, 'Slot', dftemp['StartSlot'])
    
    if dftemp.iloc[-1]['Start Date'] + dftemp.iloc[-1]['Charging Time (hh:mm:ss)'] > (dftemp.iloc[-1]['StartSlot'] + dt.timedelta(hours=2)):
        dftemp.insert(1, 'ChargeMin', (dftemp['StartSlot'] + dt.timedelta(hours=2)) - dftemp['Start Date'])
        dftemp.insert(2, 'TimeLeftCharge', dftemp['Charging Time (hh:mm:ss)'] - dftemp['ChargeMin'])
    else: 
        dftemp.insert(1, 'ChargeMin', dftemp.iloc[-1]['Charging Time (hh:mm:ss)'])
        dftemp.insert(2, 'TimeLeftCharge', dt.timedelta(seconds=0))

    if dftemp.iloc[-1]['Start Date'] + dftemp.iloc[-1]['Total Duration (hh:mm:ss)'] > (dftemp.iloc[-1]['StartSlot'] + dt.timedelta(hours=2)):
        dftemp.insert(3, 'ParkMin', (dftemp['StartSlot'] + dt.timedelta(hours=2)) - dftemp['Start Date'])
        dftemp.insert(4, 'TimeLeftPark', dftemp['Total Duration (hh:mm:ss)'] - dftemp['ChargeMin'])
    else: 
        dftemp.insert(3, 'ParkMin', dftemp.iloc[-1]['Total Duration (hh:mm:ss)'])
        dftemp.insert(4, 'TimeLeftPark', dt.timedelta(seconds=0))                      
 
    while dftemp.iloc[-1]['TimeLeftPark'] > dt.timedelta(seconds=0):
        dftemp2 = pd.DataFrame(dftemp.iloc[-1]).T
        dftemp2['Slot'] = dftemp2['Slot'] + dt.timedelta(hours=2)

        if dftemp2.iloc[-1]['TimeLeftCharge'] > dt.timedelta(hours=2):
            dftemp2['ChargeMin'] = dt.timedelta(hours=2)
            dftemp2['TimeLeftCharge'] = dftemp2['TimeLeftCharge'] - dt.timedelta(hours=2)
        else: 
            dftemp2['ChargeMin'] = dftemp2['TimeLeftCharge']
            dftemp2['TimeLeftCharge'] = dt.timedelta(seconds=0)
            
        if dftemp2.iloc[-1]['TimeLeftPark'] > dt.timedelta(hours=2):
            dftemp2['ParkMin'] = dt.timedelta(hours=2)
            dftemp2['TimeLeftPark'] = dftemp2['TimeLeftPark'] - dt.timedelta(hours=2)
        else: 
            dftemp2['ParkMin'] = dftemp2['TimeLeftPark']
            dftemp2['TimeLeftPark'] = dt.timedelta(seconds=0)        
            
            
        dftemp = pd.concat([dftemp, dftemp2])    

    final = dftemp.reset_index() 
    result = pd.concat([result, final])
    
end = time.time()
print(end - start)
# Out:
# 129.27737069129944

# %%
cols = ['index', 'Slot', 'ChargeMin', 'TimeLeftCharge', 'ParkMin',
       'TimeLeftPark', 'Station Name', 'Start Date',
        'End Date', 'StartSlot', 'EndSlot',  'Park Duration (mins)', 'Charge Duration (mins)', 'ConPerMin']

# %%
result[cols]
# Out:
#     index                Slot       ChargeMin  TimeLeftCharge         ParkMin  \
# 0   49698 2016-01-01 10:00:00 0 days 00:12:00 0 days 01:20:00 0 days 00:12:00
# 1   49698 2016-01-01 12:00:00 0 days 01:20:00 0 days 00:00:00 0 days 02:00:00
# 2   49698 2016-01-01 14:00:00 0 days 00:00:00 0 days 00:00:00 0 days 01:38:00
# 0   49710 2016-01-01 12:00:00 0 days 00:17:00 0 days 03:28:00 0 days 00:17:00
# 1   49710 2016-01-01 14:00:00 0 days 02:00:00 0 days 01:28:00 0 days 02:00:00
# ..    ...                 ...             ...             ...             ...
# 2   95360 2017-01-01 02:00:00 0 days 02:00:00 0 days 05:20:00 0 days 02:00:00
# 3   95360 2017-01-01 04:00:00 0 days 02:00:00 0 days 03:20:00 0 days 02:00:00
# 4   95360 2017-01-01 06:00:00 0 days 02:00:00 0 days 01:20:00 0 days 02:00:00
# 5   95360 2017-01-01 08:00:00 0 days 01:20:00 0 days 00:00:00 0 days 02:00:00
# 6   95360 2017-01-01 10:00:00 0 days 00:00:00 0 days 00:00:00 0 days 00:23:00
#
#       TimeLeftPark               Station Name          Start Date  \
# 0  0 days 03:38:00  PALO ALTO CA / WEBSTER #2 2016-01-01 11:48:00
# 1  0 days 01:38:00  PALO ALTO CA / WEBSTER #2 2016-01-01 11:48:00
# 2  0 days 00:00:00  PALO ALTO CA / WEBSTER #2 2016-01-01 11:48:00
# 0  0 days 03:28:00  PALO ALTO CA / WEBSTER #2 2016-01-01 13:43:00
# 1  0 days 01:28:00  PALO ALTO CA / WEBSTER #2 2016-01-01 13:43:00
# ..             ...                        ...                 ...
# 2  0 days 06:23:00  PALO ALTO CA / WEBSTER #2 2016-12-31 23:26:00
# 3  0 days 04:23:00  PALO ALTO CA / WEBSTER #2 2016-12-31 23:26:00
# 4  0 days 02:23:00  PALO ALTO CA / WEBSTER #2 2016-12-31 23:26:00
# 5  0 days 00:23:00  PALO ALTO CA / WEBSTER #2 2016-12-31 23:26:00
# 6  0 days 00:00:00  PALO ALTO CA / WEBSTER #2 2016-12-31 23:26:00
#
#               End Date           StartSlot             EndSlot  \
# 0  2016-01-01 15:39:00 2016-01-01 10:00:00 2016-01-01 16:00:00
# 1  2016-01-01 15:39:00 2016-01-01 10:00:00 2016-01-01 16:00:00
# 2  2016-01-01 15:39:00 2016-01-01 10:00:00 2016-01-01 16:00:00
# 0  2016-01-01 17:28:00 2016-01-01 12:00:00 2016-01-01 18:00:00
# 1  2016-01-01 17:28:00 2016-01-01 12:00:00 2016-01-01 18:00:00
# ..                 ...                 ...                 ...
# 2  2017-01-01 10:23:00 2016-12-31 22:00:00 2017-01-01 12:00:00
# 3  2017-01-01 10:23:00 2016-12-31 22:00:00 2017-01-01 12:00:00
# 4  2017-01-01 10:23:00 2016-12-31 22:00:00 2017-01-01 12:00:00
# 5  2017-01-01 10:23:00 2016-12-31 22:00:00 2017-01-01 12:00:00
# 6  2017-01-01 10:23:00 2016-12-31 22:00:00 2017-01-01 12:00:00
#
#    Park Duration (mins) Charge Duration (mins)  ConPerMin
# 0                  230                      92  0.0329853
# 1                  230                      92  0.0329853
# 2                  230                      92  0.0329853
# 0                  225                     225  0.0552341
# 1                  225                     225  0.0552341
# ..                  ...                    ...        ...
# 2                  657                     594  0.0992997
# 3                  657                     594  0.0992997
# 4                  657                     594  0.0992997
# 5                  657                     594  0.0992997
# 6                  657                     594  0.0992997
#
# [8727 rows x 14 columns]

# %%
resultX = result.reset_index()

# %%
pd.set_option('display.max_columns', 500)
resultX[resultX.duplicated('Slot', keep=False)].sort_values('Slot')
# Out:
#       level_0  index                Slot       ChargeMin  TimeLeftCharge  \
# 1           1  49698 2016-01-01 12:00:00 0 days 01:20:00 0 days 00:00:00
# 3           0  49710 2016-01-01 12:00:00 0 days 00:17:00 0 days 03:28:00
# 2           2  49698 2016-01-01 14:00:00 0 days 00:00:00 0 days 00:00:00
# 4           1  49710 2016-01-01 14:00:00 0 days 02:00:00 0 days 01:28:00
# 10          4  49732 2016-01-02 06:00:00 0 days 00:00:00 0 days 00:00:00
# ...       ...    ...                 ...             ...             ...
# 8716        1  95325 2016-12-31 16:00:00 0 days 01:14:00 0 days 00:00:00
# 8717        0  95346 2016-12-31 16:00:00 0 days 00:11:00 0 days 01:20:00
# 8713        1  95322 2016-12-31 16:00:00 0 days 01:42:00 0 days 00:00:00
# 8714        2  95322 2016-12-31 18:00:00 0 days 00:00:00 0 days 00:00:00
# 8718        1  95346 2016-12-31 18:00:00 0 days 01:20:00 0 days 00:00:00
#
#              ParkMin    TimeLeftPark               Station Name  \
# 1    0 days 02:00:00 0 days 01:38:00  PALO ALTO CA / WEBSTER #2
# 3    0 days 00:17:00 0 days 03:28:00  PALO ALTO CA / WEBSTER #2
# 2    0 days 01:38:00 0 days 00:00:00  PALO ALTO CA / WEBSTER #2
# 4    0 days 02:00:00 0 days 01:28:00  PALO ALTO CA / WEBSTER #2
# 10   0 days 02:00:00 0 days 02:31:00  PALO ALTO CA / WEBSTER #2
# ...              ...             ...                        ...
# 8716 0 days 01:14:00 0 days 00:00:00  PALO ALTO CA / WEBSTER #2
# 8717 0 days 00:11:00 0 days 01:59:00  PALO ALTO CA / WEBSTER #2
# 8713 0 days 02:00:00 0 days 01:51:00  PALO ALTO CA / WEBSTER #2
# 8714 0 days 01:51:00 0 days 00:00:00  PALO ALTO CA / WEBSTER #2
# 8718 0 days 01:59:00 0 days 00:00:00  PALO ALTO CA / WEBSTER #2
#
#            MAC Address            Org Name          Start Date  \
# 1     0024B100000207FA  City of Palo Alto  2016-01-01 11:48:00
# 3     0024B100000207FA  City of Palo Alto  2016-01-01 13:43:00
# 2     0024B100000207FA  City of Palo Alto  2016-01-01 11:48:00
# 4     0024B100000207FA  City of Palo Alto  2016-01-01 13:43:00
# 10    0024B100000207FA  City of Palo Alto  2016-01-01 22:43:00
# ...                ...                 ...                 ...
# 8716  0024B100000207FA  City of Palo Alto  2016-12-31 15:01:00
# 8717  0024B100000207FA  City of Palo Alto  2016-12-31 17:49:00
# 8713  0024B100000207FA  City of Palo Alto  2016-12-31 14:53:00
# 8714  0024B100000207FA  City of Palo Alto  2016-12-31 14:53:00
# 8718  0024B100000207FA  City of Palo Alto  2016-12-31 17:49:00
#
#      Start Time Zone            End Date End Time Zone  \
# 1                PST 2016-01-01 15:39:00           PST
# 3                PST 2016-01-01 17:28:00           PST
# 2                PST 2016-01-01 15:39:00           PST
# 4                PST 2016-01-01 17:28:00           PST
# 10               PST 2016-01-02 10:31:00           PST
# ...              ...                 ...           ...
# 8716             PST 2016-12-31 17:14:00           PST
# 8717             PST 2016-12-31 19:59:00           PST
# 8713             PST 2016-12-31 19:51:00           PST
# 8714             PST 2016-12-31 19:51:00           PST
# 8718             PST 2016-12-31 19:59:00           PST
#
#      Total Duration (hh:mm:ss) Charging Time (hh:mm:ss) Energy (kWh)  \
# 1              0 days 03:50:00          0 days 01:32:00      3.03464
# 3              0 days 03:45:00          0 days 03:45:00      12.4277
# 2              0 days 03:50:00          0 days 01:32:00      3.03464
# 4              0 days 03:45:00          0 days 03:45:00      12.4277
# 10             0 days 11:48:00          0 days 01:51:00      10.7521
# ...                        ...                      ...          ...
# 8716           0 days 02:13:00          0 days 02:13:00       13.012
# 8717           0 days 02:10:00          0 days 01:31:00         2.97
# 8713           0 days 04:58:00          0 days 02:49:00       16.557
# 8714           0 days 04:58:00          0 days 02:49:00       16.557
# 8718           0 days 02:10:00          0 days 01:31:00         2.97
#
#      GHG Savings (kg) Gasoline Savings (gallons) Port Type Port Number  \
# 1               1.275                      0.381   Level 2           2
# 3                5.22                       1.56   Level 2           1
# 2               1.275                      0.381   Level 2           2
# 4                5.22                       1.56   Level 2           1
# 10              4.516                      1.349   Level 2           1
# ...               ...                        ...       ...         ...
# 8716            5.465                      1.633   Level 2           2
# 8717            1.247                      0.373   Level 2           2
# 8713            6.954                      2.078   Level 2           1
# 8714            6.954                      2.078   Level 2           1
# 8718            1.247                      0.373   Level 2           2
#
#      Plug Type       Address 1       City State/Province Postal Code  \
# 1        J1772  532 Webster St  Palo Alto     California       94301
# 3        J1772  532 Webster St  Palo Alto     California       94301
# 2        J1772  532 Webster St  Palo Alto     California       94301
# 4        J1772  532 Webster St  Palo Alto     California       94301
# 10       J1772  532 Webster St  Palo Alto     California       94301
# ...        ...             ...        ...            ...         ...
# 8716     J1772  532 Webster St  Palo Alto     California       94301
# 8717     J1772  532 Webster St  Palo Alto     California       94301
# 8713     J1772  532 Webster St  Palo Alto     California       94301
# 8714     J1772  532 Webster St  Palo Alto     California       94301
# 8718     J1772  532 Webster St  Palo Alto     California       94301
#
#             Country Latitude Longitude Currency Fee             Ended By  \
# 1     United States  37.4482  -122.158      USD   0             Customer
# 3     United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 2     United States  37.4482  -122.158      USD   0             Customer
# 4     United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 10    United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# ...             ...      ...       ...      ...  ..                  ...
# 8716  United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 8717  United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 8713  United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 8714  United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
# 8718  United States  37.4482  -122.158      USD   0  Plug Out at Vehicle
#
#      Plug In Event Id Driver Postal Code Park Duration (mins)  \
# 1                1216              94024                 230
# 3                1219              94025                 225
# 2                1216              94024                 230
# 4                1219              94025                 225
# 10         1451717005              94301                 708
# ...               ...                ...                  ...
# 8716             4216              94087                 133
# 8717             4217              94539                 130
# 8713             4215              94301                 298
# 8714             4215              94301                 298
# 8718             4217              94539                 130
#
#      Charge Duration (mins)  ID       Pairlocation StartYear  \
# 1                        92  17  37.4482x-122.1582      2016
# 3                       225  17  37.4482x-122.1582      2016
# 2                        92  17  37.4482x-122.1582      2016
# 4                       225  17  37.4482x-122.1582      2016
# 10                      111  17  37.4482x-122.1582      2016
# ...                     ...  ..                ...       ...
# 8716                    133  17  37.4482x-122.1582      2016
# 8717                     91  17  37.4482x-122.1582      2016
# 8713                    169  17  37.4482x-122.1582      2016
# 8714                    169  17  37.4482x-122.1582      2016
# 8718                     91  17  37.4482x-122.1582      2016
#
#                StartSlot             EndSlot  ConPerMin
# 1    2016-01-01 10:00:00 2016-01-01 16:00:00  0.0329853
# 3    2016-01-01 12:00:00 2016-01-01 18:00:00  0.0552341
# 2    2016-01-01 10:00:00 2016-01-01 16:00:00  0.0329853
# 4    2016-01-01 12:00:00 2016-01-01 18:00:00  0.0552341
# 10   2016-01-01 22:00:00 2016-01-02 12:00:00  0.0968654
# ...                  ...                 ...        ...
# 8716 2016-12-31 14:00:00 2016-12-31 18:00:00  0.0978346
# 8717 2016-12-31 16:00:00 2016-12-31 20:00:00  0.0326374
# 8713 2016-12-31 14:00:00 2016-12-31 20:00:00  0.0979704
# 8714 2016-12-31 14:00:00 2016-12-31 20:00:00  0.0979704
# 8718 2016-12-31 16:00:00 2016-12-31 20:00:00  0.0326374
#
# [7774 rows x 42 columns]

# %%
resultX['ChargeMin'] / np.timedelta64(1, 's') / 60
# Out:
# 0        12.0
# 1        80.0
# 2         0.0
# 3        17.0
# 4       120.0
#         ...
# 8722    120.0
# 8723    120.0
# 8724    120.0
# 8725     80.0
# 8726      0.0
# Name: ChargeMin, Length: 8727, dtype: float64

# %%
resultX['ChargeMin'] = resultX['ChargeMin'] / np.timedelta64(1, 's') / 60

# %%
resultX.dtypes
# Out:
# level_0                                 int64
# index                                   int64
# Slot                           datetime64[ns]
# ChargeMin                             float64
# TimeLeftCharge                timedelta64[ns]
# ParkMin                       timedelta64[ns]
# TimeLeftPark                  timedelta64[ns]
# Station Name                           object
# MAC Address                            object
# Org Name                               object
# Start Date                     datetime64[ns]
# Start Time Zone                        object
# End Date                       datetime64[ns]
# End Time Zone                          object
# Total Duration (hh:mm:ss)     timedelta64[ns]
# Charging Time (hh:mm:ss)      timedelta64[ns]
# Energy (kWh)                           object
# GHG Savings (kg)                       object
# Gasoline Savings (gallons)             object
# Port Type                              object
# Port Number                            object
# Plug Type                              object
# Address 1                              object
# City                                   object
# State/Province                         object
# Postal Code                            object
# Country                                object
# Latitude                               object
# Longitude                              object
# Currency                               object
# Fee                                    object
# Ended By                               object
# Plug In Event Id                       object
# Driver Postal Code                     object
# Park Duration (mins)                   object
# Charge Duration (mins)                 object
# ID                                     object
# Pairlocation                           object
# StartYear                              object
# StartSlot                      datetime64[ns]
# EndSlot                        datetime64[ns]
# ConPerMin                              object
# dtype: object

# %%
resultX.insert(3, 'EnergyConsumed', resultX['ChargeMin'] * resultX['ConPerMin'].astype(float))

# %%
resultX.head()
# Out:
#    level_0  index                Slot  EnergyConsumed  ChargeMin  \
# 0        0  49698 2016-01-01 10:00:00        0.395823       12.0
# 1        1  49698 2016-01-01 12:00:00        2.638820       80.0
# 2        2  49698 2016-01-01 14:00:00        0.000000        0.0
# 3        0  49710 2016-01-01 12:00:00        0.938979       17.0
# 4        1  49710 2016-01-01 14:00:00        6.628086      120.0
#
#    TimeLeftCharge         ParkMin    TimeLeftPark               Station Name  \
# 0 0 days 01:20:00 0 days 00:12:00 0 days 03:38:00  PALO ALTO CA / WEBSTER #2
# 1 0 days 00:00:00 0 days 02:00:00 0 days 01:38:00  PALO ALTO CA / WEBSTER #2
# 2 0 days 00:00:00 0 days 01:38:00 0 days 00:00:00  PALO ALTO CA / WEBSTER #2
# 3 0 days 03:28:00 0 days 00:17:00 0 days 03:28:00  PALO ALTO CA / WEBSTER #2
# 4 0 days 01:28:00 0 days 02:00:00 0 days 01:28:00  PALO ALTO CA / WEBSTER #2
#
#         MAC Address            Org Name          Start Date Start Time Zone  \
# 0  0024B100000207FA  City of Palo Alto  2016-01-01 11:48:00             PST
# 1  0024B100000207FA  City of Palo Alto  2016-01-01 11:48:00             PST
# 2  0024B100000207FA  City of Palo Alto  2016-01-01 11:48:00             PST
# 3  0024B100000207FA  City of Palo Alto  2016-01-01 13:43:00             PST
# 4  0024B100000207FA  City of Palo Alto  2016-01-01 13:43:00             PST
#
#              End Date End Time Zone Total Duration (hh:mm:ss)  \
# 0 2016-01-01 15:39:00           PST           0 days 03:50:00
# 1 2016-01-01 15:39:00           PST           0 days 03:50:00
# 2 2016-01-01 15:39:00           PST           0 days 03:50:00
# 3 2016-01-01 17:28:00           PST           0 days 03:45:00
# 4 2016-01-01 17:28:00           PST           0 days 03:45:00
#
#   Charging Time (hh:mm:ss) Energy (kWh) GHG Savings (kg)  \
# 0          0 days 01:32:00      3.03464            1.275
# 1          0 days 01:32:00      3.03464            1.275
# 2          0 days 01:32:00      3.03464            1.275
# 3          0 days 03:45:00      12.4277             5.22
# 4          0 days 03:45:00      12.4277             5.22
#
#   Gasoline Savings (gallons) Port Type Port Number Plug Type       Address 1  \
# 0                      0.381   Level 2           2     J1772  532 Webster St
# 1                      0.381   Level 2           2     J1772  532 Webster St
# 2                      0.381   Level 2           2     J1772  532 Webster St
# 3                       1.56   Level 2           1     J1772  532 Webster St
# 4                       1.56   Level 2           1     J1772  532 Webster St
#
#         City State/Province Postal Code        Country Latitude Longitude  \
# 0  Palo Alto     California       94301  United States  37.4482  -122.158
# 1  Palo Alto     California       94301  United States  37.4482  -122.158
# 2  Palo Alto     California       94301  United States  37.4482  -122.158
# 3  Palo Alto     California       94301  United States  37.4482  -122.158
# 4  Palo Alto     California       94301  United States  37.4482  -122.158
#
#   Currency Fee             Ended By Plug In Event Id Driver Postal Code  \
# 0      USD   0             Customer             1216              94024
# 1      USD   0             Customer             1216              94024
# 2      USD   0             Customer             1216              94024
# 3      USD   0  Plug Out at Vehicle             1219              94025
# 4      USD   0  Plug Out at Vehicle             1219              94025
#
#   Park Duration (mins) Charge Duration (mins)  ID       Pairlocation  \
# 0                 230                      92  17  37.4482x-122.1582
# 1                 230                      92  17  37.4482x-122.1582
# 2                 230                      92  17  37.4482x-122.1582
# 3                 225                     225  17  37.4482x-122.1582
# 4                 225                     225  17  37.4482x-122.1582
#
#   StartYear           StartSlot             EndSlot  ConPerMin
# 0      2016 2016-01-01 10:00:00 2016-01-01 16:00:00  0.0329853
# 1      2016 2016-01-01 10:00:00 2016-01-01 16:00:00  0.0329853
# 2      2016 2016-01-01 10:00:00 2016-01-01 16:00:00  0.0329853
# 3      2016 2016-01-01 12:00:00 2016-01-01 18:00:00  0.0552341
# 4      2016 2016-01-01 12:00:00 2016-01-01 18:00:00  0.0552341

# %%
XX = resultX.groupby("Slot").mean()

# %%
XX.head(10)
# Out:
#                      level_0    index  EnergyConsumed  ChargeMin
# Slot
# 2016-01-01 10:00:00      0.0  49698.0        0.395823       12.0
# 2016-01-01 12:00:00      0.5  49704.0        1.788899       48.5
# 2016-01-01 14:00:00      1.5  49704.0        3.314043       60.0
# 2016-01-01 16:00:00      2.0  49710.0        4.860597       88.0
# 2016-01-01 22:00:00      0.0  49732.0        7.458635       77.0
# 2016-01-02 00:00:00      1.0  49732.0        3.293423       34.0
# 2016-01-02 02:00:00      2.0  49732.0        0.000000        0.0
# 2016-01-02 04:00:00      3.0  49732.0        0.000000        0.0
# 2016-01-02 06:00:00      2.0  49734.0        1.910066       25.5
# 2016-01-02 08:00:00      3.0  49734.0        3.670322       49.0

# %%
XX.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
plt.plot(XX.head(20)['EnergyConsumed'], '.')
plt.show()

# %%
plt.plot(XX['EnergyConsumed'], '.')
plt.show()

# %%
XX[XX['EnergyConsumed'] == 0]
# Out:
#                      level_0  index  EnergyConsumed  ChargeMin  TimeOnly
# Slot
# 2016-01-02 02:00:00        2  49732             0.0        0.0  02:00:00
# 2016-01-02 04:00:00        3  49732             0.0        0.0  04:00:00
# 2016-01-02 22:00:00        2  49791             0.0        0.0  22:00:00
# 2016-01-03 00:00:00        3  49791             0.0        0.0  00:00:00
# 2016-01-03 12:00:00        3  99616             0.0        0.0  12:00:00
# ...                      ...    ...             ...        ...       ...
# 2016-12-23 22:00:00        3  94623             0.0        0.0  22:00:00
# 2016-12-24 00:00:00        4  94623             0.0        0.0  00:00:00
# 2016-12-24 02:00:00        5  94623             0.0        0.0  02:00:00
# 2016-12-30 06:00:00        5  95152             0.0        0.0  06:00:00
# 2017-01-01 10:00:00        6  95360             0.0        0.0  10:00:00
#
# [519 rows x 5 columns]

# %%
XX.plot(y='EnergyConsumed', figsize=(15,10))
plt.show()

# %%
XX['TimeOnly'] = XX.index.time

# %%
XX.head()
# Out:
#                      level_0  index  EnergyConsumed  ChargeMin  TimeOnly
# Slot
# 2016-01-01 10:00:00        0  49698        0.395823       12.0  10:00:00
# 2016-01-01 12:00:00        1  99408        3.577799       97.0  12:00:00
# 2016-01-01 14:00:00        3  99408        6.628086      120.0  14:00:00
# 2016-01-01 16:00:00        2  49710        4.860597       88.0  16:00:00
# 2016-01-01 22:00:00        0  49732        7.458635       77.0  22:00:00

# %%
XXX = XX.groupby('TimeOnly').sum()
XXX.reset_index()
XXX.head()
# Out:
#           level_0     index  EnergyConsumed  ChargeMin
# TimeOnly
# 00:00:00      677  22644279     1267.359146    14491.0
# 02:00:00      842  19390138      704.121090     7878.0
# 04:00:00     1057  20595395      521.752330     6075.0
# 06:00:00     1255  47744598     1874.008252    24673.0
# 08:00:00     1172  60812973     3925.964194    53606.0

# %%
XXX.plot.bar(y='EnergyConsumed')
plt.show()
